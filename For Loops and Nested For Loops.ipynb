# %% [markdown]
# ![image.png](attachment:91e776bc-5ee8-442f-bc9a-d7e680501cc2.png)

# %%
integers = [1,2,3,4,5]

# %%
for number in integers:
    print(number)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
print(number)
# Out:
# 5

# %%
integers = [1,2,3,4,5]
for number in integers:
    print('Hi')
# Out:
# Hi
# Hi
# Hi
# Hi
# Hi

# %%
integers = [1, 2, 3, 4, 5]

for number in integers:
    print("Hi " * number5)
# Out:
# Hi
# Hi Hi
# Hi Hi Hi
# Hi Hi Hi Hi
# Hi Hi Hi Hi Hi
