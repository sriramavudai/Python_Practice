# %% [markdown]
# ![image.png](attachment:a149ccc3-3a0a-44d9-a33b-4551a238d14d.png)

# %%
n = 0

while n < 5:
    print(n)
    n=n+1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
m = 1

while m < 5:
    print(m)
    m=m+1
# Out:
# 1
# 2
# 3
# 4
